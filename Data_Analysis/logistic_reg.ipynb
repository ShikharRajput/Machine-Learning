# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
file = pd.read_csv("Dataset-master\Social_Network_Ads.csv")

# %%
file.tail()
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1

# %%
file.shape
# Out:
# (400, 5)

# %%
file.corr()
# Out:
#                   User ID       Age  EstimatedSalary  Purchased
# User ID          1.000000 -0.000721         0.071097   0.007120
# Age             -0.000721  1.000000         0.155238   0.622454
# EstimatedSalary  0.071097  0.155238         1.000000   0.362083
# Purchased        0.007120  0.622454         0.362083   1.000000

# %%
x,y = file['Age'],file['EstimatedSalary']
x.head(),y.head()
# Out:
# (0    19
#  1    35
#  2    26
#  3    27
#  4    19
#  Name: Age, dtype: int64, 0    19000
#  1    20000
#  2    43000
#  3    57000
#  4    76000
#  Name: EstimatedSalary, dtype: int64)

# %%
sb.pairplot(file)

# %%
sb.regplot(x,y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.3, random_state=2)

# %%
x_train.tail(),x_test.tail(),y_train.tail(),y_test.tail()
# Out:
# (299    46
#  22     48
#  72     20
#  15     29
#  168    29
#  Name: Age, dtype: int64, 175    23
#  99     28
#  366    58
#  362    47
#  10     26
#  Name: Age, dtype: int64, 299    117000
#  22      41000
#  72      23000
#  15      80000
#  168    148000
#  Name: EstimatedSalary, dtype: int64, 175    28000
#  99     37000
#  366    47000
#  362    50000
#  10     80000
#  Name: EstimatedSalary, dtype: int64)

# %%
sb.regplot(x_test, y_test)

# %%
sb.regplot(x_train, y_train)

# %%
lr = LinearRegression()
lr1 = lr.fit(x_train.values.reshape(-1,1),y_train.values.reshape(-1,1))

# %%
print(lr1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
x_train.shape,y_train.shape
# Out:
# ((280,), (280,))

# %%
pre = lr.predict(x_test.values.reshape(-1,1))
pre[-1:-10:-1]
# Out:
# array([[64787.34010083],
#        [73913.76396455],
#        [78694.27170269],
#        [65656.52332595],
#        [63483.56526316],
#        [76086.72202735],
#        [68698.66461386],
#        [74782.94718967],
#        [64787.34010083]])

# %%
sb.regplot(x_train.values.reshape(-1,1),lr.predict(x_train.values.reshape(-1,1)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-163-9c6181e7960d> in <module>()
# ----> 1 sb.regplot(x_train.values.reshape(-1,1),lr.predict(x_train.values.reshape(-1,1)))
#
# ~\Anaconda3\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     788     scatter_kws["marker"] = marker
#     789     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 790     plotter.plot(ax, scatter_kws, line_kws)
#     791     return ax
#     792
#
# ~\Anaconda3\lib\site-packages\seaborn\regression.py in plot(self, ax, scatter_kws, line_kws)
#     340             self.scatterplot(ax, scatter_kws)
#     341         if self.fit_reg:
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
x1_train = sc.fit_transform(x_train.values.reshape(-1,1))
x1_train
# Out:
# C:\Users\SHIKHAR RAJPUT\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# array([[ 0.02273414],
#        [ 0.79431698],
#        [-0.26660943],
#        [ 0.89076483],
#        [ 0.3120777 ],
#        [-0.26660943],
#        [-0.26660943],
#        [ 1.46945196],
#        [-0.07371372],
#        [-0.84529656],
#        [-0.07371372],
#        [-0.26660943],
#        [ 0.21562985],
#        [-0.26660943],
#        [ 0.11918199],
#        [ 1.95169124],
#        [-1.03819227],
#        [ 0.3120777 ],
#        [ 2.04813909],
#        [-1.13464012],
#        [ 0.21562985],
#        [-0.26660943],
#        [-0.65240085],
#        [ 0.21562985],
#        [ 0.40852556],
#        [-1.13464012],
#        [-0.07371372],
#        [ 1.08366054],
#        [ 0.89076483],
#        [-0.07371372],
#        [-0.55595299],
#        [-1.13464012],
# ...

# %%
x1_test = sc.fit_transform(x_test.values.reshape(-1,1))
x1_test
# Out:
# C:\Users\SHIKHAR RAJPUT\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# array([[-0.78516104],
#        [-1.53293345],
#        [-0.03738862],
#        [-0.78516104],
#        [ 1.55162776],
#        [ 0.8973269 ],
#        [-1.34599035],
#        [-0.87863259],
#        [ 0.24302603],
#        [-0.13086017],
#        [-1.25251879],
#        [-1.4394619 ],
#        [-0.50474638],
#        [ 0.71038379],
#        [-0.22433172],
#        [-0.41127483],
#        [-1.71987655],
#        [ 2.11245707],
#        [ 1.45815621],
#        [-1.06557569],
#        [-0.03738862],
#        [ 0.71038379],
#        [-0.69168948],
#        [-0.13086017],
#        [-1.15904724],
#        [ 0.71038379],
#        [ 0.71038379],
#        [ 0.24302603],
#        [ 0.61691224],
#        [-0.50474638],
#        [-1.25251879],
#        [ 0.33649759],
# ...

# %%
x_train.shape, x_test.shape, x1_train.shape, x1_test.shape,
# Out:
# ((280,), (120,), (280, 1), (120, 1))

# %%
from sklearn.linear_model import LogisticRegression

# %%
logr = LogisticRegression()

# %%
logr1 = logr.fit(x_train.values.reshape(-1,1),y_train.values.reshape(-1,1))
# Out:
# C:\Users\SHIKHAR RAJPUT\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
logr1
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
prer = logr.predict(x1_test.reshape(-1,1))
prer
# Out:
# array([19000, 19000, 19000, 19000, 19000, 19000, 19000, 19000, 19000,
#        19000, 19000, 19000, 19000, 19000, 19000, 19000, 19000, 85000,
#        19000, 19000, 19000, 19000, 19000, 19000, 19000, 19000, 19000,
#        19000, 19000, 19000, 19000, 19000, 19000, 19000, 19000, 19000,
#        19000, 19000, 19000, 19000, 19000, 19000, 19000, 19000, 19000,
#        19000, 19000, 19000, 19000, 19000, 19000, 19000, 19000, 19000,
#        19000, 19000, 19000, 19000, 19000, 19000, 19000, 85000, 85000,
#        19000, 19000, 19000, 19000, 19000, 19000, 85000, 19000, 85000,
#        19000, 19000, 19000, 19000, 85000, 19000, 19000, 19000, 19000,
#        19000, 19000, 19000, 19000, 19000, 19000, 19000, 19000, 19000,
#        19000, 19000, 85000, 19000, 19000, 19000, 19000, 19000, 19000,
#        19000, 19000, 19000, 19000, 19000, 19000, 19000, 19000, 19000,
#        19000, 19000, 19000, 19000, 19000, 19000, 19000, 19000, 19000,
#        85000, 19000, 19000], dtype=int64)

# %%
x1_test[:5],x_test[:5]
# Out:
# (array([[-0.78516104],
#         [-1.53293345],
#         [-0.03738862],
#         [-0.78516104],
#         [ 1.55162776]]), 94     29
#  32     21
#  225    37
#  157    29
#  356    54
#  Name: Age, dtype: int64)

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y,test)
